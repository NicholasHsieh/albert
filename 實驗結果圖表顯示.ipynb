# %%
#ROUND1
import numpy as np
import matplotlib.pyplot as plt

data_1 = [
    (600,37.5),(1000,39.5), (1500,39.0), (2000,37.5)
]
data_2 = [
  (600,37.5),(1000,37.5), (1500,38.0), (2000,39.0)
]
data_3 = [
  (600,37.0),(1000,38.0), (1500,39.5), (2000,38.0)
]
data_4 = [
  (600,37.5),(1000,37.5), (1500,39.0), (2000,39.0)
]

def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)

plt.title("Round 1 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#ROUND2
import numpy as np
import matplotlib.pyplot as plt

data_1 = [
    (600,30.8),(1000,33.8), (1500,34.6), (2000,36.4)
]
data_2 = [
  (600,33.0),(1000,35.2), (1500,35.4), (2000,35.8)
]
data_3 = [
  (600,33.0),(1000,33.2), (1500,36.0), (2000,36.3)
]
data_4 = [
  (600,33.4),(1000,35.0), (1500,35.8), (2000,36.2)
]

def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)

plt.title("Round 2 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#ROUND3
import numpy as np
import matplotlib.pyplot as plt

data_1 = [
    (600,36.0),(1000,35.6), (1500,36.6), (2000,38.8), (3000,39.0)
]
data_2 = [
  (600,36.0),(1000,35.7), (1500,37.4), (2000,38.0), (3000,38.6)
]
data_3 = [
  (600,35.2),(1000,36.0), (1500,37.6), (2000,38.4), (3000,38.8)
]
data_4 = [
  (600,36.4),(1000,38.0), (1500,37.4), (2000,38.0), (3000,38.4)
]

def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)

plt.title("Round 3 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#ROUND4
import numpy as np
import matplotlib.pyplot as plt

data_1 = [
    (600,41.4),(1000,43.6), (1500,42.8), (2000,44.4), (3000,44.4)
]
data_2 = [
  (600,42.0),(1000,43.0), (1500,43.2), (2000,43.0), (3000,44.6)
]
data_3 = [
  (600,42.2),(1000,43.0), (1500,43.2), (2000,44.4), (3000,44.4)
]
data_4 = [
  (600,42.0),(1000,42.8), (1500,43.2), (2000,44.2), (3000,44.0)
]
data_5 = [
  (600,42.2),(1000,43.0), (1500,43.2), (2000,44.4), (3000,44.4)
]
def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)

plt.title("Round 4 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#ROUND5
import numpy as np
import matplotlib.pyplot as plt

data_1 = [
    (600,39.0),(1000,39.4), (1500,39.8), (2000,40.8), (3000,40.6)
]
data_2 = [
  (600,39.8),(1000,39.8), (1500,40.8), (2000,40.4), (3000,40.8)
]
data_3 = [
  (600,38.6),(1000,39.2), (1500,39.2), (2000,39.6), (3000,40.8)
]
data_4 = [
  (600,40.4),(1000,40.2), (1500,39.8), (2000,40.0), (3000,40.8)
]
data_5 = [
  (600,42.2),(1000,43.0), (1500,43.2), (2000,44.4), (3000,44.4)
]
def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)

plt.title("Round 5 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#ROUND6
import numpy as np
import matplotlib.pyplot as plt

data_1 = [
    (600,39.0),(1000,39.4), (1500,39.8), (2000,40.8), (3000,40.4), (4000,40.8)
]
data_2 = [
  (600,39.8),(1000,39.8), (1500,40.8), (2000,40.6), (3000,40.6),(4000,40.8)
]
data_3 = [
  (600,38.6),(1000,39.2), (1500,39.2), (2000,40.8), (3000,40.8),(4000,41)
]
data_4 = [
  (600,40.4),(1000,40.2), (1500,39.8), (2000,40.8), (3000,40.8),(4000,41)
]
data_5 = [
  (600,46.18),(1000,46.79), (1500,46.99), (2000,46.79), (3000,46.39), (4000,46.99)
]
data_6 = [
  (600,46.18),(1000,46.59), (1500,46.79), (2000,46.59), (3000,46.79),(4000,47.39)
]
data_7 = [
  (600,45.78),(1000,45.98), (1500,46.18), (2000,46.59), (3000,47.19),(4000,47.39)
]
data_8 = [
  (600,46.39),(1000,46.39), (1500,46.59), (2000,46.39), (3000,47.39),(4000,47.79)
]

def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

def plotData4(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert_X')

def plotData5(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert_X')

def plotData6(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD_X')

def plotData7(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD_X')

# plotData(plt, data_1)
# plotData1(plt, data_2)
# plotData2(plt, data_3)
# plotData3(plt, data_4)
plotData4(plt, data_5)
plotData5(plt, data_6)
plotData6(plt, data_7)
plotData7(plt, data_8)

plt.title("Round 6 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#ROUND7
import numpy as np
import matplotlib.pyplot as plt

data_1 = [
    (600,38.2),(1000,39), (1500,39.4), (2000,39)#, (3000,40.4), (4000,40.8)
]
data_2 = [
  (600,38.4),(1000,38.6), (1500,39.6), (2000,39.2)#, (3000,40.6),(4000,40.8)
]
data_3 = [
  (600,38.4),(1000,39), (1500,39), (2000,39)#, (3000,40.8),(4000,41)
]
data_4 = [
  (600,38.6),(1000,38.9), (1500,39), (2000,39.2)#, (3000,40.8),(4000,41)
]
data_5 = [
  (600,46.18),(1000,46.79), (1500,46.99), (2000,46.79)#, (3000,46.39), (4000,46.99)
]
data_6 = [
  (600,46.18),(1000,46.59), (1500,46.79), (2000,46.59)#, (3000,46.79),(4000,47.39)
]
data_7 = [
  (600,45.78),(1000,45.98), (1500,46.18), (2000,46.59)#, (3000,47.19),(4000,47.39)
]
data_8 = [
  (600,46.39),(1000,46.39), (1500,46.59), (2000,46.39)#, (3000,47.39),(4000,47.79)
]

def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

def plotData4(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert_X')

def plotData5(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert_X')

def plotData6(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD_X')

def plotData7(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD_X')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)
# plotData4(plt, data_5)
# plotData5(plt, data_6)
# plotData6(plt, data_7)
# plotData7(plt, data_8)

plt.title("Round 6 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#Average(600~2000 R2-R5 3000 R3-R5)
import numpy as np
import matplotlib.pyplot as plt

# data_1 = [
#     (200,41),(400,45.8), (2000,47.8), (3000,49.2)
# ]
data_1 = [
  (600,36.8),(1000,38.1), (1500,38.45), (2000,40.1), (3000,41.33)
]
data_2 = [
  (600,37.7),(1000,38.43), (1500,39.2), (2000,39.3), (3000,41.33)
]
data_3 = [
  (600,37.25),(1000,37.85), (1500,39.0), (2000,39.68), (3000,41.33)
]
data_4 = [
  (600,38.05),(1000,39.0), (1500,39.05), (2000,39.6), (3000,41.07)
]

def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)

plt.title("Average TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
#Average(600~2000 R3-R5 3000 R3-R5)
import numpy as np
import matplotlib.pyplot as plt

# data_1 = [
#     (200,41),(400,45.8), (2000,47.8), (3000,49.2)
# ]
data_1 = [
  (600,38.8),(1000,39.53), (1500,39.73), (2000,41.33), (3000,41.33)
]
data_2 = [
  (600,39.27),(1000,39.5), (1500,40.47), (2000,40.47), (3000,41.33)
]
data_3 = [
  (600,38.67),(1000,39.4), (1500,40.0), (2000,40.8), (3000,41.33)
]
data_4 = [
  (600,39.6),(1000,40.33), (1500,40.13), (2000,40.73), (3000,41.07)
]

def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert')

def plotData1(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert')

def plotData2(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'bert + DRCD')

def plotData3(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, label = 'albert + DRCD')

plotData(plt, data_1)
plotData1(plt, data_2)
plotData2(plt, data_3)
plotData3(plt, data_4)

plt.title("Average TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xlabel("Samples")
plt.ylabel("Accuracy")
#plt.plot(x, data_1, label = 'class_a')
#plt.plot(x, data_2, label = 'class_b')
#plt.plot(x, data_3, label = 'class_b')
plt.legend()

# %%
import matplotlib.pyplot as plt
x = ['bert', 'bert + DRCD', 'albert', 'albert + DRCD']
class_a = [47.5, 47.1, 47.3, 46.5]
class_b = [40.6, 40.8, 40.8, 40.8]

plt.title("Situation Prediction")
plt.xlabel("Method")
plt.ylabel("Accuracy")
plt.ylim(30, 55)
#plt.bar(x, class_a, label = 'class_a')
rects1 = plt.bar(x, class_a, label = '3000X', align = "edge", color='#FFC000', width = 0.3)
rects2 = plt.bar(x, class_b, label = '3000', align = "edge", color='#E46C0A', width = -0.3)
plt.legend()
for rect in rects1:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), ha="center", va="bottom")
for rect in rects2:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), ha="center", va="bottom")
plt.show()

# %%
#%%
import matplotlib.pyplot as plt
bar_width = 0.2

x = ['bert', 'bertX']
class_a = [ 38.8, 43.86]
plt.title("Situation Prediction")
plt.xlabel("Method")
plt.ylabel("Accuracy")
plt.ylim(35, 47)
#plt.bar(x, class_a, label = 'class_a')
rects1 = plt.bar(x, class_a, color='#E46C0A', width=0.6)
plt.legend()
for rect in rects1:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), ha="center", va="bottom")

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np                # 資料處理套件
import pandas as pd               # 資料處理套件
import matplotlib.pyplot as plt   # 資料視覺化套件

accident = pd.read_csv("Average.csv")
accident.head(10)    # 顯示前3筆資料
# Out:
#              num     type      exact  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0           bert   NUM600  34.766667        30.8       37.50        36.0
# 1         albert   NUM600  35.500000        33.0       37.50        36.0
# 2    bert + DRCD   NUM600  35.066667        33.0       37.00        35.2
# 3  albert + DRCD   NUM600  35.766667        33.4       37.50        36.4
# 4           bert  NUM1000  36.300000        33.8       39.50        35.6
# 5         albert  NUM1000  36.133333        35.2       37.50        35.7
# 6    bert + DRCD  NUM1000  35.733333        33.2       38.00        36.0
# 7  albert + DRCD  NUM1000  36.833333        35.0       37.50        38.0
# 8           bert  NUM1500  37.626667        34.6       41.68        36.6
# 9         albert  NUM1500  37.943333        35.4       41.03        37.4

# %%
col_count = 4                  # 由於有3個月，設定類別基數為3
bar_width = 0.2                # 設定長條圖每個長條寬度
index = np.arange(col_count)   # 依據3個類別(3個月)設定索引值，便於後續長條圖的位置設定

# 自原始資料中分別擷取5個肇事原因的件數
A = accident[accident.type == "NUM600"]["exact"]          
B = accident[accident.type == "NUM1000"]["exact"]
C = accident[accident.type == "NUM1500"]["exact"]
D = accident[accident.type == "NUM2000"]["exact"]
# E = accident[accident.reason == "else"]["count"]

# 設定bar的圖型
A = plt.bar(index,         # 索引值代表A肇事原因的長條位置，如index=[0,1,2]，分別在3個月的第一個位置
           A,              # 設定長條圖的資料 
           bar_width,      # 設定長條寬度
           alpha=.6,       # 設定透明度
           label="600")# 設定標籤 
B = plt.bar(index+0.2,     # 索引值為A的索引值+0.2(長條寬度)，顯示於A長條的旁邊一個長條寬度的位置
            B,
            bar_width,
            alpha=.6,
            label="1000") 
C = plt.bar(index+0.4,
            C,
            bar_width,
            alpha=.6,
            label="1500")
D = plt.bar(index+0.6,
            D,
            bar_width,
            alpha=.6,
            label="2000")
# E = plt.bar(index+0.8,
#             E,
#             bar_width,
#             alpha=.6,
#             label="else")

# 使得每個長條圖上顯示資料標籤，詳見：[https://stackoverflow.com/questions/40489821/how-to-write-text-above-the-bars-on-a-bar-plot-python](http://)
def createLabels(data):                   # 自定義函數，為引用plusone團隊
    for item in data:
        height = item.get_height()
        plt.text(
            item.get_x()+item.get_width()/2., 
            height*1.01, 
            '%.1f' % height,
            ha = "center",
            va = "bottom",
        )
createLabels(A)
createLabels(B)
createLabels(C)
createLabels(D)
# createLabels(E)

# 定義標籤
plt.ylabel("Accuracy")          # 設定y軸標題 
plt.xlabel("Samples")            # 設定x軸標題
plt.title("Round 3 TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xticks(index+ .25 / 2 ,("bert", "bert + DRCD", "albert", "albert + DRCD"))  #.xticks為x軸文字(為了置中所以+0.3/2)
plt.ylim(30.0, 43.0)                 # 設定y軸範圍
plt.legend(prop = {'size':9})    # 設定圖例及其大小
plt.grid(True)                   # 顯示格線

# 儲存圖檔
# plt.savefig("Bar chart of car accident.jpg",   # 儲存圖檔
#             bbox_inches='tight',               # 去除座標軸占用的空間
#             pad_inches=0.0)                    # 去除所有白邊
# plt.close()      # 關閉圖表

# %%
col_count = 4                  # 由於有3個月，設定類別基數為3
bar_width = 0.2                # 設定長條圖每個長條寬度
index = np.arange(col_count)   # 依據3個類別(3個月)設定索引值，便於後續長條圖的位置設定

# 自原始資料中分別擷取5個肇事原因的件數
A = accident[accident.type == "NUM600"]["exact"]          
B = accident[accident.type == "NUM1000"]["exact"]
C = accident[accident.type == "NUM1500"]["exact"]
D = accident[accident.type == "NUM2000"]["exact"]
# E = accident[accident.reason == "else"]["count"]

# 設定bar的圖型
A = plt.bar(index,         # 索引值代表A肇事原因的長條位置，如index=[0,1,2]，分別在3個月的第一個位置
           A,              # 設定長條圖的資料 
           bar_width,      # 設定長條寬度
           alpha=.6,       # 設定透明度
           label="600")# 設定標籤 
B = plt.bar(index+0.2,     # 索引值為A的索引值+0.2(長條寬度)，顯示於A長條的旁邊一個長條寬度的位置
            B,
            bar_width,
            alpha=.6,
            label="1000") 
C = plt.bar(index+0.4,
            C,
            bar_width,
            alpha=.6,
            label="1500")
D = plt.bar(index+0.6,
            D,
            bar_width,
            alpha=.6,
            label="2000")

# E = plt.bar(index+0.8,
#             E,
#             bar_width,
#             alpha=.6,
#             label="else")

# 使得每個長條圖上顯示資料標籤，詳見：[https://stackoverflow.com/questions/40489821/how-to-write-text-above-the-bars-on-a-bar-plot-python](http://)
def createLabels(data):                   # 自定義函數，為引用plusone團隊
    for item in data:
        height = item.get_height()
        plt.text(
            item.get_x()+item.get_width()/2., 
            height*1.01, 
            '%.2f' % height,
            ha = "center",
            va = "bottom",
        )
createLabels(A)
createLabels(B)
createLabels(C)
createLabels(D)
# createLabels(E)

# 定義標籤
plt.ylabel("Accuracy")          # 設定y軸標題 
plt.xlabel("Samples")            # 設定x軸標題
plt.title("Average TEST ", {'fontsize' : 17})  # 設定標題、文字大小
plt.xticks(index+ .25 / 2 ,("bert", "bert + DRCD", "albert", "albert + DRCD"))  #.xticks為x軸文字(為了置中所以+0.3/2)
plt.ylim(30.0, 50.0)                 # 設定y軸範圍
plt.legend(prop = {'size':9})    # 設定圖例及其大小
plt.grid(True)                   # 顯示格線

# 儲存圖檔
# plt.savefig("Bar chart of car accident.jpg",   # 儲存圖檔
#             bbox_inches='tight',               # 去除座標軸占用的空間
#             pad_inches=0.0)                    # 去除所有白邊
# plt.close()      # 關閉圖表
